# %%
import pandas as pd

df = pd.DataFrame({'Math': [4, 4, 7, 8, 12, 13, 15, 18, 22, 23, 23, 25],
                   'Eng': [2, 5, 4, 7, 7, 8, 5, 4, 5, 11, 13, 8]})
df.shape # Hiển thị kích thước của dataframe (số hàng và cột)
# Out:
# (12, 2)

# %%
df['bin1'] = pd.qcut(df['Math'], q=5)  # Chia cột "Math" thành 5 khoảng giá trị với số lượng phần tử bằng nhau
df  # Hiển thị dataframe
# Out:
#     Math  Eng          bin1
# 0      4    2  (3.999, 7.2]
# 1      4    5  (3.999, 7.2]
# 2      7    4  (3.999, 7.2]
# 3      8    7   (7.2, 12.4]
# 4     12    7   (7.2, 12.4]
# 5     13    8  (12.4, 16.8]
# 6     15    5  (12.4, 16.8]
# 7     18    4  (16.8, 22.8]
# 8     22    5  (16.8, 22.8]
# 9     23   11  (22.8, 25.0]
# 10    23   13  (22.8, 25.0]
# 11    25    8  (22.8, 25.0]

# %%
df['bin1'].value_counts()  # Đếm số lượng giá trị thuộc mỗi khoảng trong "bin1"
# Out:
# bin1
# (3.999, 7.2]    3
# (22.8, 25.0]    3
# (7.2, 12.4]     2
# (12.4, 16.8]    2
# (16.8, 22.8]    2
# Name: count, dtype: int64

# %%
df['bin2'] = pd.qcut(df['Math'], q=[0, .2, .4, .6, .8, 1])  # Chia "Math" thành 5 khoảng với tỷ lệ 20% mỗi khoảng
df  # Hiển thị dataframe
# Out:
#     Math  Eng          bin1          bin2
# 0      4    2  (3.999, 7.2]  (3.999, 7.2]
# 1      4    5  (3.999, 7.2]  (3.999, 7.2]
# 2      7    4  (3.999, 7.2]  (3.999, 7.2]
# 3      8    7   (7.2, 12.4]   (7.2, 12.4]
# 4     12    7   (7.2, 12.4]   (7.2, 12.4]
# 5     13    8  (12.4, 16.8]  (12.4, 16.8]
# 6     15    5  (12.4, 16.8]  (12.4, 16.8]
# 7     18    4  (16.8, 22.8]  (16.8, 22.8]
# 8     22    5  (16.8, 22.8]  (16.8, 22.8]
# 9     23   11  (22.8, 25.0]  (22.8, 25.0]
# 10    23   13  (22.8, 25.0]  (22.8, 25.0]
# 11    25    8  (22.8, 25.0]  (22.8, 25.0]

# %%
df['bin3'] = pd.qcut(df['Math'], q=[0, .2, .4, .6, .8, 1], labels=['A', 'B', 'C', 'D', 'E'])  
# Gán nhãn "A" đến "E" cho các khoảng trong cột "Math" chia tỷ lệ 20% mỗi khoảng
df  # Hiển thị dataframe
# Out:
#     Math  Eng          bin1 bin3
# 0      4    2  (3.999, 7.2]    A
# 1      4    5  (3.999, 7.2]    A
# 2      7    4  (3.999, 7.2]    A
# 3      8    7   (7.2, 12.4]    B
# 4     12    7   (7.2, 12.4]    B
# 5     13    8  (12.4, 16.8]    C
# 6     15    5  (12.4, 16.8]    C
# 7     18    4  (16.8, 22.8]    D
# 8     22    5  (16.8, 22.8]    D
# 9     23   11  (22.8, 25.0]    E
# 10    23   13  (22.8, 25.0]    E
# 11    25    8  (22.8, 25.0]    E

# %%
df['bin4'] = pd.cut(df['Eng'], bins=[0, 5, 8, float('Inf')], labels=['Bad', 'OK', 'Good'])  
# Chia cột "Eng" thành các khoảng và gán nhãn "Bad", "OK", "Good"
df  # Hiển thị dataframe
# Out:
#     Math  Eng          bin1 bin3  bin4
# 0      4    2  (3.999, 7.2]    A   Bad
# 1      4    5  (3.999, 7.2]    A   Bad
# 2      7    4  (3.999, 7.2]    A   Bad
# 3      8    7   (7.2, 12.4]    B    OK
# 4     12    7   (7.2, 12.4]    B    OK
# 5     13    8  (12.4, 16.8]    C    OK
# 6     15    5  (12.4, 16.8]    C   Bad
# 7     18    4  (16.8, 22.8]    D   Bad
# 8     22    5  (16.8, 22.8]    D   Bad
# 9     23   11  (22.8, 25.0]    E  Good
# 10    23   13  (22.8, 25.0]    E  Good
# 11    25    8  (22.8, 25.0]    E    OK

# %%
df['bin4'].value_counts()  # Đếm số lượng giá trị thuộc mỗi khoảng trong "bin4"
# Out:
# bin4
# Bad     6
# OK      4
# Good    2
# Name: count, dtype: int64

# %%
# Label Encoding và One-Hot Encoding
import pandas as pd

gdp = [11, 22, 33, 44, 55, 66, 77]
countries = ['Spain', 'France', 'Spain', 'Germany', 'France']
df = pd.DataFrame(list(zip(gdp, countries)), columns=['GDP', 'Countries'])  # Tạo dataframe từ danh sách GDP và countries
df  # Hiển thị dataframe
# Out:
#    GDP Countries
# 0   11     Spain
# 1   22    France
# 2   33     Spain
# 3   44   Germany
# 4   55    France

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()  
df['labelCountries'] = label_encoder.fit_transform(df['Countries'])  
# Mã hóa các giá trị trong cột "Countries" thành số (Label Encoding)
df  # Hiển thị dataframe
# Out:
#    GDP Countries  labelCountries
# 0   11     Spain               2
# 1   22    France               0
# 2   33     Spain               2
# 3   44   Germany               1
# 4   55    France               0

# %%
dfOneHotEncoding = pd.get_dummies(df.Countries, prefix='Country')  
# Thực hiện One-Hot Encoding trên cột "Countries"
print(dfOneHotEncoding.head())  # Hiển thị kết quả One-Hot Encoding
# Out:
#    Country_France  Country_Germany  Country_Spain
# 0           False            False           True
# 1            True            False          False
# 2           False            False           True
# 3           False             True          False
# 4            True            False          False

# %%
df = pd.concat([df, dfOneHotEncoding], axis=1)  # Ghép dataframe ban đầu với dataframe kết quả One-Hot Encoding
df  # Hiển thị dataframe sau khi ghép
# Out:
#    GDP Countries  labelCountries  Country_France  Country_Germany  \
# 0   11     Spain               2           False            False
# 1   22    France               0            True            False
# 2   33     Spain               2           False            False
# 3   44   Germany               1           False             True
# 4   55    France               0            True            False
#
#    Country_Spain
# 0           True
# 1          False
# 2           True
# 3          False
# 4          False

# %%
from sklearn.preprocessing import LabelBinarizer
y = LabelBinarizer().fit_transform(df.Countries)  
# Thực hiện Label Binarizer (tương tự One-Hot Encoding)
y  # Hiển thị kết quả
# Out:
# array([[0, 0, 1],
#        [1, 0, 0],
#        [0, 0, 1],
#        [0, 1, 0],
#        [1, 0, 0]])

# %%
from sklearn.preprocessing import OneHotEncoder
y = OneHotEncoder().fit_transform(df[['Countries']]).toarray()  
# Sử dụng OneHotEncoder từ sklearn để mã hóa cột "Countries"
print(y)  # Hiển thị kết quả
# Out:
# [[0. 0. 1.]
#  [1. 0. 0.]
#  [0. 0. 1.]
#  [0. 1. 0.]
#  [1. 0. 0.]]

# %%
# Chuẩn hóa dữ liệu với MaxAbsScaler và MinMaxScaler
import pandas as pd

year = [2010,2011,2012,2013,2014,2015]
salaryHCM = [8.5,9.0,10.5,12.0,11.0,10.0]
salaryLA = [5.5,6.0,6.0,5.5,6.0,5.0]

df = pd.DataFrame(list(zip(year, salaryHCM,salaryLA)), columns=['Year', 'HCM','LA'])  
# Tạo dataframe với thông tin lương của HCM và LA theo năm
df  # Hiển thị dataframe
# Out:
#    Year   HCM   LA
# 0  2010   8.5  5.5
# 1  2011   9.0  6.0
# 2  2012  10.5  6.0
# 3  2013  12.0  5.5
# 4  2014  11.0  6.0
# 5  2015  10.0  5.0

# %%
max_la = df['LA'].abs().max()  # Tính giá trị lớn nhất của cột "LA"
df['macLA'] = df['LA'] / max_la  # Chuẩn hóa giá trị của cột "LA" bằng giá trị max
df  # Hiển thị dataframe sau chuẩn hóa
# Out:
#    Year   HCM   LA     macLA
# 0  2010   8.5  5.5  0.916667
# 1  2011   9.0  6.0  1.000000
# 2  2012  10.5  6.0  1.000000
# 3  2013  12.0  5.5  0.916667
# 4  2014  11.0  6.0  1.000000
# 5  2015  10.0  5.0  0.833333

# %%
max_hcm = df['HCM'].abs().max() # Tính giá trị lớn nhất của cột "HCM"
df['macHCM'] = df['HCM'] / max_hcm # Chuẩn hóa giá trị của cột "HCM" bằng giá trị max
df  # Hiển thị dataframe sau chuẩn hóa
# Out:
#    Year   HCM   LA     macLA    macHCM
# 0  2010   8.5  5.5  0.916667  0.708333
# 1  2011   9.0  6.0  1.000000  0.750000
# 2  2012  10.5  6.0  1.000000  0.875000
# 3  2013  12.0  5.5  0.916667  1.000000
# 4  2014  11.0  6.0  1.000000  0.916667
# 5  2015  10.0  5.0  0.833333  0.833333

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()  
scaled = scaler.fit_transform(df[['HCM','LA']])  
# Chuẩn hóa cột "HCM" và "LA" bằng MaxAbsScaler
scaled_df = pd.DataFrame(scaled, columns=df[['HCM','LA']].columns)  
# Chuyển kết quả chuẩn hóa thành dataframe
print(scaled_df)  # Hiển thị dataframe đã chuẩn hóa
# Out:
#         HCM        LA
# 0  0.708333  0.916667
# 1  0.750000  1.000000
# 2  0.875000  1.000000
# 3  1.000000  0.916667
# 4  0.916667  1.000000
# 5  0.833333  0.833333

# %%
vSc = scaler.transform([[4.5,5.75]])  # Chuẩn hóa giá trị 4.5 và 5.75 bằng MaxAbsScaler
vSc  # Hiển thị kết quả
# Out:
# C:\Users\Star\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MaxAbsScaler was fitted with feature names
#   warnings.warn(
# array([[0.375     , 0.95833333]])

# %%
vR = scaler.inverse_transform([[0.5,0.8]])  # Chuyển đổi ngược lại từ giá trị đã chuẩn hóa sang giá trị ban đầu
vR  # Hiển thị kết quả
# Out:
# array([[6. , 4.8]])

# %%
vR = scaler.inverse_transform([[0.65,1.9]])# Chuyển đổi ngược lại từ giá trị đã chuẩn hóa sang giá trị ban đầu
vR  # Hiển thị kết quả
# Out:
# array([[ 7.8, 11.4]])

# %%
min_la = df['LA'].min()  # Tính giá trị nhỏ nhất của cột "LA"
max_la = df['LA'].max()  # Tính giá trị lớn nhất của cột "LA"
df['mmcLA'] = (df['LA'] - min_la) / (max_la - min_la)  
# Chuẩn hóa cột "LA" bằng Min-Max Scaling
df  # Hiển thị dataframe sau chuẩn hóa
# Out:
#    Year   HCM   LA     macLA    macHCM  mmcLA
# 0  2010   8.5  5.5  0.916667  0.708333    0.5
# 1  2011   9.0  6.0  1.000000  0.750000    1.0
# 2  2012  10.5  6.0  1.000000  0.875000    1.0
# 3  2013  12.0  5.5  0.916667  1.000000    0.5
# 4  2014  11.0  6.0  1.000000  0.916667    1.0
# 5  2015  10.0  5.0  0.833333  0.833333    0.0

# %%
df[['HCM','LA']].describe() #Bảng thống kê mô tả HCM và LA trong df
# Out:
#              HCM        LA
# count   6.000000  6.000000
# mean   10.166667  5.666667
# std     1.290994  0.408248
# min     8.500000  5.000000
# 25%     9.250000  5.500000
# 50%    10.250000  5.750000
# 75%    10.875000  6.000000
# max    12.000000  6.000000

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()  
scaled = scaler.fit_transform(df[['HCM','LA']])  
# Chuẩn hóa cột "HCM" và "LA" bằng MinMaxScaler
scaled_df = pd.DataFrame(scaled, columns=df[['HCM','LA']].columns)  
# Chuyển kết quả chuẩn hóa thành dataframe
print(scaled_df)  # Hiển thị dataframe đã chuẩn hóa
# Out:
#         HCM   LA
# 0  0.000000  0.5
# 1  0.142857  1.0
# 2  0.571429  1.0
# 3  1.000000  0.5
# 4  0.714286  1.0
# 5  0.428571  0.0

# %%
# Chuẩn hóa dữ liệu bằng z-score
mean_la = df['LA'].mean()  # Tính giá trị trung bình của cột "LA"
std_la = df['LA'].std()  # Tính độ lệch chuẩn của cột "LA"
df['zLA'] = (df['LA'] - mean_la) / std_la  # Chuẩn hóa cột "LA" bằng z-score
df  # Hiển thị dataframe sau chuẩn hóa
# Out:
#    Year   HCM   LA     macLA    macHCM  mmcLA       zLA
# 0  2010   8.5  5.5  0.916667  0.708333    0.5 -0.408248
# 1  2011   9.0  6.0  1.000000  0.750000    1.0  0.816497
# 2  2012  10.5  6.0  1.000000  0.875000    1.0  0.816497
# 3  2013  12.0  5.5  0.916667  1.000000    0.5 -0.408248
# 4  2014  11.0  6.0  1.000000  0.916667    1.0  0.816497
# 5  2015  10.0  5.0  0.833333  0.833333    0.0 -1.632993

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()  
scaled = scaler.fit_transform(df[['HCM','LA']])  
# Chuẩn hóa cột "HCM" và "LA" bằng StandardScaler
scaled_df = pd.DataFrame(scaled, columns=df[['HCM','LA']].columns)  
# Chuyển kết quả chuẩn hóa thành dataframe
print(scaled_df)  # Hiển thị dataframe đã chuẩn hóa
# Out:
#         HCM        LA
# 0 -1.414214 -0.447214
# 1 -0.989949  0.894427
# 2  0.282843  0.894427
# 3  1.555635 -0.447214
# 4  0.707107  0.894427
# 5 -0.141421 -1.788854

# %%
# Áp dụng một hàm biến đổi đơn giản
def funcX(x):
    return x*x + 1  # Hàm trả về x^2 + 1

df['TransformX'] = funcX(df[["LA"]])  # Áp dụng hàm funcX lên cột "LA"
df  # Hiển thị dataframe sau khi áp dụng hàm
# Out:
#    Year   HCM   LA     macLA    macHCM  mmcLA       zLA  TransformX
# 0  2010   8.5  5.5  0.916667  0.708333    0.5 -0.408248       31.25
# 1  2011   9.0  6.0  1.000000  0.750000    1.0  0.816497       37.00
# 2  2012  10.5  6.0  1.000000  0.875000    1.0  0.816497       37.00
# 3  2013  12.0  5.5  0.916667  1.000000    0.5 -0.408248       31.25
# 4  2014  11.0  6.0  1.000000  0.916667    1.0  0.816497       37.00
# 5  2015  10.0  5.0  0.833333  0.833333    0.0 -1.632993       26.00

# %% [markdown]
# Bài tập
# Sinh viên tính vẽ biểu đồ phân phối lương trung bình của HCM
# Tính skenewss và kurtorsis của lương trung bình HCM
# Sử dụng hàm log để transform dữ liệu
# Vẽ biểu đồ phân phối của dữ liệu lương trung bình của HCM sau khi transform
# Tính skenewss và kurtorsis của dữ liệu lương trụng bình HCM sau khi transform

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Vẽ biểu đồ phân phối lương trung bình của HCM
sns.histplot(df['HCM'], kde=True)
plt.title('Phân phối lương trung bình HCM')
plt.xlabel('Lương HCM')
plt.ylabel('Tần suất')
plt.show()

from scipy.stats import skew, kurtosis

# Tính skewness và kurtosis
skewness_before = skew(df['HCM'])
kurtosis_before = kurtosis(df['HCM'])

print(f'Skewness trước khi transform: {skewness_before}')
print(f'Kurtosis trước khi transform: {kurtosis_before}')

import numpy as np

# Transform dữ liệu bằng log
df['HCM_log'] = np.log(df['HCM'])

# Kiểm tra dữ liệu sau khi transform
df[['HCM', 'HCM_log']].head()

# Vẽ biểu đồ phân phối sau khi transform
sns.histplot(df['HCM_log'], kde=True)
plt.title('Phân phối lương trung bình HCM sau khi transform')
plt.xlabel('Lương HCM (log)')
plt.ylabel('Tần suất')
plt.show()

# Tính skewness và kurtosis sau khi transform
skewness_after = skew(df['HCM_log'])
kurtosis_after = kurtosis(df['HCM_log'])

print(f'Skewness sau khi transform: {skewness_after}')
print(f'Kurtosis sau khi transform: {kurtosis_after}')
# Out:
# Skewness trước khi transform: 0.05656854249492543
# Kurtosis trước khi transform: -1.154399999999999
# Skewness sau khi transform: -0.08557801425278959
# Kurtosis sau khi transform: -1.200702452149693
