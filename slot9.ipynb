# %% [markdown]
# <h3>Supervised</h3>
# <img src="z5909436702981_94576087a7d011fbbb803db5996f634b.jpg" style="margin : 30px ;width:800px"></img>
# <br>
# feature: HSgrade(%)
# <br>
# target: poverty(%)
# <br>
# poverty = f(HSgrade)
# <br>
# target = response variable
# <br>
# feature = explanatory variable
# <br>
# Relationship ?
# <br>
# n= (corr)Correlation(x,y) thuộc [-1,1]
# <br>
# n<0 -> negative => x tăng y giảm, x giảm y tăng
# <br>
# n=0 -> no
# <br>
# n>0 -> positive => x tăng y tăng, x giảm y giảm
# <br>
# AI -> tối ưu -> math -> cực trị
# <br>
# Data = Fit + Residual
# <br>
# Residual là độ lệch được tính bằng hàm số toán học so với dữ liệu thực tế (e)
# <br>
# Fit là dữ liệu nằm trên đường thẳng
# <br>
# ei = yi - y^i (lệch = thực tế - dự báo)
# <br>
# <img src="z5909560501538_e3ba09a087fbfcb2f591970936db0675.jpg" style="margin : 30px ;width:800px"></img>
# <br>
# poverty = B0 +B1 * HSgrade (Simple Linear Regression)
# <br>
# ei = yi - y^i = yi -(B0 + B1 *xi)
# <br>
# Tổng ei^2 = Tổng (yi-(B0+B1*xi))^2
# <br>
# <img src="z5909594245935_f7e7574e9bb059b3ae48fc6f52d15fbe.jpg" style="margin : 30px ;width:800px"></img>
# <br>
# Tổng (yi-(B0+B1*xi))^2 : (f(B0B1))
# <br>
# <img src="z5909569573007_b910ac589265893cc9afe6f28fc5520c.jpg" style="margin : 30px ;width:800px"></img>
# <br>
# <img src="Screenshot 2024-10-08 192524.png"></img>
# =
# <img src="Screenshot 2024-10-08 192448.png"></img>
# <br>
# <img src="z5909639336167_8910aa779596face37ee21b8b0101437.jpg" style="margin : 30px ;width:800px"></img>
# <br>
# <img src="Screenshot 2024-10-08 193150.png"></img>
# <br>
# <img src="z5909707456676_506a42c7ed37ee1c8cf1c9e1d1367a5e.jpg"></img>
# <br>
# Y = f(X)= B0 +B1 * X

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
df = pd.read_excel("ProfitRate.xlsx")
df
# Out:
#    TimeAds  ProfitRate
# 0      0.5           1
# 1      2.0           2
# 2      4.0           7
# 3      5.0           8
# 4      3.0           5
# 5      6.0           8
# 6      7.0           9
# 7      9.0          12
# 8      8.0          10
# 9      1.0           3

# %%
sns.pairplot(df[['TimeAds','ProfitRate']], diag_kind='kde', kind='reg')
plt.show()

# %%
#Tập dữ liệu Input (đặc trưng) và Output (mục tiêu)
x = df[['TimeAds']].values #explanatory = feature
y = df[['ProfitRate']].values #response = target

# Đảm bảo dữ liệu là kiểu số thực
x = x.astype(float)
y = y.astype(float)

# %%
#split dataset into training set and test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x,y, test_size= 0.4, random_state=16)

# %%
X_train
# Out:
# array([[8.],
#        [3.],
#        [5.],
#        [2.],
#        [6.],
#        [1.]])

# %%
y_train
# Out:
# array([[10.],
#        [ 5.],
#        [ 8.],
#        [ 2.],
#        [ 8.],
#        [ 3.]])

# %%
from sklearn import linear_model

model = linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("B0 = ",model.intercept_)
print("B1 = ",model.coef_)
# Out:
# B0 =  [1.215311]
# B1 =  [[1.14832536]]

# %%
from sklearn import metrics

y_test_pred = model.predict(X_test)

print('Score or RSquare: ', model.score(X_test,y_test_pred))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test,y_test_pred))
print('Mean Squared Error: ', metrics.mean_squared_error(y_test,y_test_pred))
print('Mean Absolute percentage Error: ', metrics.mean_absolute_percentage_error(y_test,y_test_pred))
# Out:
# Score or RSquare:  1.0
# Mean Absolute Error:  0.6710526315789472
# Mean Squared Error:  0.5773162244454112
# Mean Absolute percentage Error:  0.2563321181742236
